# %%
import os
import logging
from pathlib import Path
from dotenv import load_dotenv
import hashlib
import requests
import pandas as pd
import json
import time
import pyarrow as pa
from datetime import datetime, timezone
from deltalake import write_deltalake
from tqdm import tqdm

# %%
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(name)s - %(levelname)s - %(message)s")
logging.info("Initialising configuration...")
# Out:
# 2025-11-21 12:50:09,001 - root - INFO - Initialising configuration...

# %%
load_dotenv()
# Out:
# True

# %%
project_root = Path.cwd()
input_csv_path = project_root / Path("..") / "resources" / "vietnam_provinces_geocoded.csv"
input_csv_path.resolve()
# Out:
# PosixPath('/home/tan/geo-weather-lake/resources/vietnam_provinces_geocoded.csv')

# %%
MINIO_ENDPOINT = "http://localhost:9000"
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")
WEATHERBIT_API_KEY = os.getenv("WEATHERBIT_API_KEY")

storage_options = {
    "AWS_ACCESS_KEY_ID": AWS_ACCESS_KEY_ID,
    "AWS_SECRET_ACCESS_KEY": AWS_SECRET_ACCESS_KEY,
    "AWS_ENDPOINT_URL": MINIO_ENDPOINT,
    "AWS_ALLOW_HTTP": "true",
    "AWS_S3_ALLOW_UNSAFE_RENAME": "true"
}

BRONZE_BUCKET = 'weather-bronze'
BRONZE_TABLE_PATH = f's3://{BRONZE_BUCKET}/weather_events'

logging.info("Configuration loaded for historical ingestion.")
# Out:
# 2025-11-21 12:50:09,022 - root - INFO - Configuration loaded for historical ingestion.

# %%
logging.info(f"Reading geocoded locations from {input_csv_path}...")
df_locations = pd.read_csv(input_csv_path)
locations_to_fetch = df_locations.to_dict('records')
logging.info(f"Successfully loaded {len(locations_to_fetch)} locations to fetch historical data for.")
# Out:
# 2025-11-21 12:50:09,034 - root - INFO - Reading geocoded locations from /home/tan/geo-weather-lake/notebooks/../resources/vietnam_provinces_geocoded.csv...
# 2025-11-21 12:50:09,037 - root - INFO - Successfully loaded 34 locations to fetch historical data for.

# %%
locations_to_fetch
# Out:
# [{'name': 'Hải Phòng', 'latitude': 20.8623278, 'longitude': 106.6799266},
#  {'name': 'Hồ Chí Minh', 'latitude': 10.7755254, 'longitude': 106.7021047},
#  {'name': 'Cà Mau', 'latitude': 9.0180177, 'longitude': 105.0869724},
#  {'name': 'Gia Lai', 'latitude': 14.0201373, 'longitude': 108.6354524},
#  {'name': 'Đồng Tháp', 'latitude': 10.425183, 'longitude': 105.9271362},
#  {'name': 'Cần Thơ', 'latitude': 10.0362046, 'longitude': 105.7872656},
#  {'name': 'Lâm Đồng', 'latitude': 11.6614957, 'longitude': 108.1335279},
#  {'name': 'An Giang', 'latitude': 10.3188672, 'longitude': 105.0432488},
#  {'name': 'Quảng Ngãi', 'latitude': 14.9953739, 'longitude': 108.691729},
#  {'name': 'Quảng Trị', 'latitude': 17.2166964, 'longitude': 106.9548246},
#  {'name': 'Hưng Yên', 'latitude': 20.6065846, 'longitude': 106.2843471},
#  {'name': 'Cao Bằng', 'latitude': 22.7426936, 'longitude': 106.1060926},
#  {'name': 'Lào Cai', 'latitude': 22.3069302, 'longitude': 104.1829592},
#  {'name': 'Ninh BÌnh', 'latitude': 20.2421142, 'longitude': 105.9746207},
#  {'name': 'Khánh Hòa', 'latitude': 12.2980751, 'longitude': 108.9950386},
#  {'name': 'Thái Nguyên', 'latitude': 21.9610968, 'longitude': 105.8440789},
#  {'name': 'Tây Ninh', 'latitude': 11.0800527, 'longitude': 106.2610531},
#  {'name': 'Sơn La', 'latitude': 21.2276769, 'longitude': 104.1575944},
#  {'name': 'Nghệ An', 'latitude': 19.1976001, 'longitude': 105.060676},
#  {'name': 'Phú Thọ', 'latitude': 21.3007538, 'longitude': 105.1349604},
#  {'name': 'Huế', 'latitude': 16.4639321, 'longitude': 107.5863388},
#  {'name': 'Lạng Sơn', 'latitude': 21.8487579, 'longitude': 106.6140692},
#  {'name': 'Quảng Ninh', 'latitude': 21.1718046, 'longitude': 107.2012742},
#  {'name': 'Đà Nẵng', 'latitude': 16.068, 'longitude': 108.212},
#  {'name': 'Hà Tĩnh', 'latitude': 18.3504832, 'longitude': 105.7623047},
#  {'name': 'Lai Châu', 'latitude': 22.2921668, 'longitude': 103.1798662},
#  {'name': 'Bắc Ninh', 'latitude': 21.3282166, 'longitude': 106.4625257},
#  {'name': 'Điện Biên', 'latitude': 21.6546566, 'longitude': 103.2168632},
#  {'name': 'Đồng Nai', 'latitude': 11.4285446, 'longitude': 107.1624245},
#  {'name': 'Tuyên Quang', 'latitude': 22.3382057, 'longitude': 105.0715846},
#  {'name': 'Vĩnh Long', 'latitude': 10.046765, 'longitude': 106.2947443},
#  {'name': 'Thanh Hóa', 'latitude': 19.9781573, 'longitude': 105.4816107},
#  {'name': 'Đắk Lắk', 'latitude': 12.8741856, 'longitude': 108.7979302},
#  {'name': 'Hà Nội', 'latitude': 21.0283334, 'longitude': 105.854041}]

# %%
def fetch_historical_data(api_key: str, locations: list, start_date: str, end_date: str):
    """
    Fetches hourly historical weather data for a list of locations and enriches it with province names.
    """
    if not api_key:
        logging.error("Weatherbit API Key is missing.")
        raise ValueError("API Key not provided.")
    
    BASE_URL = 'http://api.weatherbit.io/v2.0/history/hourly'
    all_historical_observations = []

    logging.info(f"Fetching historical data from {start_date} to {end_date} for {len(locations)} locations.")

    for location in tqdm(locations, desc="Fetching data for locations"):
        params = {
            'key': api_key,
            'lat': location['latitude'],
            'lon': location['longitude'],
            'start_date': start_date,
            'end_date': end_date
        }

        try:
            response = requests.get(BASE_URL, params=params, timeout=20)

            if response.status_code == 200:
                try:
                    data = response.json()
                except json.JSONDecodeError:
                    logging.warning(f"Received non-JSON response for '{location['name']}'. Skipping.")
                    continue

                data = response.json()
                metadata = {key: value for key, value in data.items() if key != 'data'}
                observations = data.get('data', [])

                for obs in observations:
                    metadata_obs = metadata.copy()
                    metadata_obs.update(obs)
                    metadata_obs['place_name'] = location['name']

                    all_historical_observations.append(metadata_obs)
            else:
                logging.error(
                    f"Failed to fetch data for '{location['name']}'. "
                    f"Status Code: {response.status_code}, Response: {response.text}"
                )
            
            time.sleep(1.1)

        except requests.exceptions.RequestException as e:
            logging.error(f"A request error occurred for '{location['name']}': {e}")

    logging.info(f"Total historical records fetched: {len(all_historical_observations)}")

    return all_historical_observations

# %%
print("Running a test run:")
start_date_str = "2025-10-30"
end_date_str   = "2025-10-31"

test_res = fetch_historical_data(WEATHERBIT_API_KEY, locations_to_fetch[:1], start_date_str, end_date_str)
# Out:
# 2025-11-21 12:50:09,061 - root - INFO - Fetching historical data from 2025-10-30 to 2025-10-31 for 1 locations.
# Running a test run:
# Fetching data for locations: 100%|██████████| 1/1 [00:01<00:00,  1.74s/it]
# 2025-11-21 12:50:10,808 - root - INFO - Total historical records fetched: 24

# %%
print(json.dumps(test_res, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 23.8,
#     "azimuth": 110.9,
#     "clouds": 100,
#     "datetime": "2025-10-30:00",
#     "dewpt": 22,
#     "dhi": 64,
#     "dni": 574,
#     "elev_angle": 13.7,
#     "ghi": 193,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 0,
#     "pres": 1015,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 94,
#     "slp": 1016,
#     "snow": 0,
#     "solar_rad": 70,
#     "temp": 23,
#     "timestamp_local": "2025-10-30T07:00:00",
#     "timestamp_utc": "2025-10-30T00:00:00",
#     "ts": 1761782400,
#     "uv": 0.7,
#     "vis": 16,
#     "weather": {
#       "icon": "c04d",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 10,
#     "wind_gust_spd": 2.3,
#     "wind_spd": 2.06,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 23.8,
#     "azimuth": 118.4,
#     "clouds": 100,
#     "datetime": "2025-10-30:01",
#     "dewpt": 22,
#     "dhi": 90,
#     "dni": 760,
#     "elev_angle": 26.5,
#     "ghi": 422,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 0.25,
#     "pres": 1016,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 94,
#     "slp": 1016,
#     "snow": 0,
#     "solar_rad": 104,
#     "temp": 23,
#     "timestamp_local": "2025-10-30T08:00:00",
#     "timestamp_utc": "2025-10-30T01:00:00",
#     "ts": 1761786000,
#     "uv": 1,
#     "vis": 16,
#     "weather": {
#       "icon": "c04d",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 20,
#     "wind_gust_spd": 2.1,
#     "wind_spd": 1.54,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 25,
#     "azimuth": 128.7,
#     "clouds": 100,
#     "datetime": "2025-10-30:02",
#     "dewpt": 21.2,
#     "dhi": 106,
#     "dni": 852,
#     "elev_angle": 38.2,
#     "ghi": 626,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 0,
#     "pres": 1016,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 83,
#     "slp": 1016,
#     "snow": 0,
#     "solar_rad": 129,
#     "temp": 24.3,
#     "timestamp_local": "2025-10-30T09:00:00",
#     "timestamp_utc": "2025-10-30T02:00:00",
#     "ts": 1761789600,
#     "uv": 1.5,
#     "vis": 16,
#     "weather": {
#       "icon": "c04d",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 34,
#     "wind_gust_spd": 2.4,
#     "wind_spd": 1.47,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 24.8,
#     "azimuth": 143.6,
#     "clouds": 100,
#     "datetime": "2025-10-30:03",
#     "dewpt": 21.4,
#     "dhi": 115,
#     "dni": 902,
#     "elev_angle": 47.9,
#     "ghi": 778,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 0,
#     "pres": 1016,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 85,
#     "slp": 1016,
#     "snow": 0,
#     "solar_rad": 143,
#     "temp": 24.1,
#     "timestamp_local": "2025-10-30T10:00:00",
#     "timestamp_utc": "2025-10-30T03:00:00",
#     "ts": 1761793200,
#     "uv": 2.1,
#     "vis": 16,
#     "weather": {
#       "icon": "c04d",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 32,
#     "wind_gust_spd": 4.1,
#     "wind_spd": 2.01,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 24.9,
#     "azimuth": 164.7,
#     "clouds": 100,
#     "datetime": "2025-10-30:04",
#     "dewpt": 21.9,
#     "dhi": 120,
#     "dni": 925,
#     "elev_angle": 54.1,
#     "ghi": 862,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 0,
#     "pres": 1015,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 87,
#     "slp": 1015,
#     "snow": 0,
#     "solar_rad": 150,
#     "temp": 24.2,
#     "timestamp_local": "2025-10-30T11:00:00",
#     "timestamp_utc": "2025-10-30T04:00:00",
#     "ts": 1761796800,
#     "uv": 2.4,
#     "vis": 16,
#     "weather": {
#       "icon": "c04d",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 19,
#     "wind_gust_spd": 3.8,
#     "wind_spd": 1.58,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 26.6,
#     "azimuth": 189.8,
#     "clouds": 100,
#     "datetime": "2025-10-30:05",
#     "dewpt": 20.8,
#     "dhi": 121,
#     "dni": 928,
#     "elev_angle": 54.8,
#     "ghi": 871,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 0,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 73,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 155,
#     "temp": 26,
#     "timestamp_local": "2025-10-30T12:00:00",
#     "timestamp_utc": "2025-10-30T05:00:00",
#     "ts": 1761800400,
#     "uv": 2.7,
#     "vis": 16,
#     "weather": {
#       "icon": "c04d",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 70,
#     "wind_gust_spd": 3.09,
#     "wind_spd": 3.09,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 25.4,
#     "azimuth": 212.2,
#     "clouds": 100,
#     "datetime": "2025-10-30:06",
#     "dewpt": 22,
#     "dhi": 117,
#     "dni": 909,
#     "elev_angle": 49.7,
#     "ghi": 803,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 0,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 85,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 144,
#     "temp": 24.7,
#     "timestamp_local": "2025-10-30T13:00:00",
#     "timestamp_utc": "2025-10-30T06:00:00",
#     "ts": 1761804000,
#     "uv": 2.2,
#     "vis": 16,
#     "weather": {
#       "icon": "c04d",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 266,
#     "wind_gust_spd": 2.6,
#     "wind_spd": 1.94,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 26.6,
#     "azimuth": 228.4,
#     "clouds": 100,
#     "datetime": "2025-10-30:07",
#     "dewpt": 20.8,
#     "dhi": 108,
#     "dni": 866,
#     "elev_angle": 40.5,
#     "ghi": 665,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 1.5,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 73,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 118,
#     "temp": 26,
#     "timestamp_local": "2025-10-30T14:00:00",
#     "timestamp_utc": "2025-10-30T07:00:00",
#     "ts": 1761807600,
#     "uv": 1.6,
#     "vis": 16,
#     "weather": {
#       "icon": "r01d",
#       "code": 500,
#       "description": "Light rain"
#     },
#     "wind_dir": 60,
#     "wind_gust_spd": 3.3,
#     "wind_spd": 3.09,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 24.9,
#     "azimuth": 239.5,
#     "clouds": 100,
#     "datetime": "2025-10-30:08",
#     "dewpt": 23,
#     "dhi": 94,
#     "dni": 786,
#     "elev_angle": 29.2,
#     "ghi": 471,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 5.25,
#     "pres": 1013,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 94,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 67,
#     "temp": 24,
#     "timestamp_local": "2025-10-30T15:00:00",
#     "timestamp_utc": "2025-10-30T08:00:00",
#     "ts": 1761811200,
#     "uv": 1.1,
#     "vis": 16,
#     "weather": {
#       "icon": "r02d",
#       "code": 501,
#       "description": "Moderate rain"
#     },
#     "wind_dir": 90,
#     "wind_gust_spd": 3.6,
#     "wind_spd": 1.54,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 24,
#     "azimuth": 247.5,
#     "clouds": 100,
#     "datetime": "2025-10-30:09",
#     "dewpt": 23,
#     "dhi": 71,
#     "dni": 629,
#     "elev_angle": 16.6,
#     "ghi": 244,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 3.5,
#     "pres": 1013,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 100,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 57,
#     "temp": 23,
#     "timestamp_local": "2025-10-30T16:00:00",
#     "timestamp_utc": "2025-10-30T09:00:00",
#     "ts": 1761814800,
#     "uv": 0.7,
#     "vis": 16,
#     "weather": {
#       "icon": "r01d",
#       "code": 500,
#       "description": "Light rain"
#     },
#     "wind_dir": 40,
#     "wind_gust_spd": 4.1,
#     "wind_spd": 2.06,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 24.2,
#     "azimuth": 253.7,
#     "clouds": 100,
#     "datetime": "2025-10-30:10",
#     "dewpt": 22.5,
#     "dhi": 27,
#     "dni": 213,
#     "elev_angle": 3.4,
#     "ghi": 30,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 3.25,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 95,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 22,
#     "temp": 23.3,
#     "timestamp_local": "2025-10-30T17:00:00",
#     "timestamp_utc": "2025-10-30T10:00:00",
#     "ts": 1761818400,
#     "uv": 0.6,
#     "vis": 9,
#     "weather": {
#       "icon": "r01n",
#       "code": 500,
#       "description": "Light rain"
#     },
#     "wind_dir": 199,
#     "wind_gust_spd": 4.1,
#     "wind_spd": 2.09,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 24,
#     "azimuth": 258.8,
#     "clouds": 100,
#     "datetime": "2025-10-30:11",
#     "dewpt": 23,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -10.3,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 2.5,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 100,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 23,
#     "timestamp_local": "2025-10-30T18:00:00",
#     "timestamp_utc": "2025-10-30T11:00:00",
#     "ts": 1761822000,
#     "uv": 0,
#     "vis": 16,
#     "weather": {
#       "icon": "r01n",
#       "code": 500,
#       "description": "Light rain"
#     },
#     "wind_dir": 20,
#     "wind_gust_spd": 3.7,
#     "wind_spd": 2.06,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 24,
#     "azimuth": 263.5,
#     "clouds": 100,
#     "datetime": "2025-10-30:12",
#     "dewpt": 23,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -24.1,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 1,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 100,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 23,
#     "timestamp_local": "2025-10-30T19:00:00",
#     "timestamp_utc": "2025-10-30T12:00:00",
#     "ts": 1761825600,
#     "uv": 0,
#     "vis": 15,
#     "weather": {
#       "icon": "r01n",
#       "code": 500,
#       "description": "Light rain"
#     },
#     "wind_dir": 360,
#     "wind_gust_spd": 3.1,
#     "wind_spd": 2.57,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 24,
#     "azimuth": 268.2,
#     "clouds": 100,
#     "datetime": "2025-10-30:13",
#     "dewpt": 23,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -38.1,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 0.25,
#     "pres": 1015,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 100,
#     "slp": 1016,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 23,
#     "timestamp_local": "2025-10-30T20:00:00",
#     "timestamp_utc": "2025-10-30T13:00:00",
#     "ts": 1761829200,
#     "uv": 0,
#     "vis": 16,
#     "weather": {
#       "icon": "a05n",
#       "code": 741,
#       "description": "Fog"
#     },
#     "wind_dir": 330,
#     "wind_gust_spd": 2.8,
#     "wind_spd": 1.54,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 24,
#     "azimuth": 273.8,
#     "clouds": 100,
#     "datetime": "2025-10-30:14",
#     "dewpt": 23,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -52.1,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 0.75,
#     "pres": 1015,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 100,
#     "slp": 1016,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 23,
#     "timestamp_local": "2025-10-30T21:00:00",
#     "timestamp_utc": "2025-10-30T14:00:00",
#     "ts": 1761832800,
#     "uv": 0,
#     "vis": 16,
#     "weather": {
#       "icon": "d02n",
#       "code": 301,
#       "description": "Drizzle"
#     },
#     "wind_dir": 343,
#     "wind_gust_spd": 2.3,
#     "wind_spd": 0.51,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 24,
#     "azimuth": 282.4,
#     "clouds": 100,
#     "datetime": "2025-10-30:15",
#     "dewpt": 23,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -66,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 1.25,
#     "pres": 1016,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 100,
#     "slp": 1016,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 23,
#     "timestamp_local": "2025-10-30T22:00:00",
#     "timestamp_utc": "2025-10-30T15:00:00",
#     "ts": 1761836400,
#     "uv": 0,
#     "vis": 13,
#     "weather": {
#       "icon": "r01n",
#       "code": 500,
#       "description": "Light rain"
#     },
#     "wind_dir": 329,
#     "wind_gust_spd": 2.1,
#     "wind_spd": 1.03,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 24,
#     "azimuth": 306.2,
#     "clouds": 88,
#     "datetime": "2025-10-30:16",
#     "dewpt": 22.7,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -78.9,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 0,
#     "pres": 1015,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 98,
#     "slp": 1015,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 23.1,
#     "timestamp_local": "2025-10-30T23:00:00",
#     "timestamp_utc": "2025-10-30T16:00:00",
#     "ts": 1761840000,
#     "uv": 0,
#     "vis": 16,
#     "weather": {
#       "icon": "a05n",
#       "code": 741,
#       "description": "Fog"
#     },
#     "wind_dir": 125,
#     "wind_gust_spd": 2.3,
#     "wind_spd": 1.41,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 23.8,
#     "azimuth": 40.4,
#     "clouds": 100,
#     "datetime": "2025-10-30:17",
#     "dewpt": 22,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -81.3,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 0,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 94,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 23,
#     "timestamp_local": "2025-10-31T00:00:00",
#     "timestamp_utc": "2025-10-30T17:00:00",
#     "ts": 1761843600,
#     "uv": 0,
#     "vis": 16,
#     "weather": {
#       "icon": "c04n",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 360,
#     "wind_gust_spd": 2.57,
#     "wind_spd": 2.57,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 23.7,
#     "azimuth": 74.6,
#     "clouds": 98,
#     "datetime": "2025-10-30:18",
#     "dewpt": 22.1,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -69.1,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 0.25,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 95,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 22.9,
#     "timestamp_local": "2025-10-31T01:00:00",
#     "timestamp_utc": "2025-10-30T18:00:00",
#     "ts": 1761847200,
#     "uv": 0,
#     "vis": 16,
#     "weather": {
#       "icon": "c04n",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 336,
#     "wind_gust_spd": 2.3,
#     "wind_spd": 1.66,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 23.6,
#     "azimuth": 84.8,
#     "clouds": 91,
#     "datetime": "2025-10-30:19",
#     "dewpt": 21.8,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -55.3,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 0,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 94,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 22.8,
#     "timestamp_local": "2025-10-31T02:00:00",
#     "timestamp_utc": "2025-10-30T19:00:00",
#     "ts": 1761850800,
#     "uv": 0,
#     "vis": 16,
#     "weather": {
#       "icon": "c04n",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 327,
#     "wind_gust_spd": 2.5,
#     "wind_spd": 1.23,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 23.8,
#     "azimuth": 90.8,
#     "clouds": 100,
#     "datetime": "2025-10-30:20",
#     "dewpt": 22,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -41.3,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 0,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 94,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 23,
#     "timestamp_local": "2025-10-31T03:00:00",
#     "timestamp_utc": "2025-10-30T20:00:00",
#     "ts": 1761854400,
#     "uv": 0,
#     "vis": 13,
#     "weather": {
#       "icon": "c04n",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 10,
#     "wind_gust_spd": 2.3,
#     "wind_spd": 2.06,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 22.9,
#     "azimuth": 95.6,
#     "clouds": 100,
#     "datetime": "2025-10-30:21",
#     "dewpt": 22,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -27.3,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 0,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 100,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 22,
#     "timestamp_local": "2025-10-31T04:00:00",
#     "timestamp_utc": "2025-10-30T21:00:00",
#     "ts": 1761858000,
#     "uv": 0,
#     "vis": 16,
#     "weather": {
#       "icon": "a05n",
#       "code": 741,
#       "description": "Fog"
#     },
#     "wind_dir": 10,
#     "wind_gust_spd": 2.5,
#     "wind_spd": 2.06,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 22.9,
#     "azimuth": 100.3,
#     "clouds": 100,
#     "datetime": "2025-10-30:22",
#     "dewpt": 22,
#     "dhi": 0,
#     "dni": 0,
#     "elev_angle": -13.4,
#     "ghi": 0,
#     "h_angle": null,
#     "pod": "n",
#     "precip": 0,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 100,
#     "slp": 1014,
#     "snow": 0,
#     "solar_rad": 0,
#     "temp": 22,
#     "timestamp_local": "2025-10-31T05:00:00",
#     "timestamp_utc": "2025-10-30T22:00:00",
#     "ts": 1761861600,
#     "uv": 0,
#     "vis": 10,
#     "weather": {
#       "icon": "a05n",
#       "code": 741,
#       "description": "Fog"
#     },
#     "wind_dir": 10,
#     "wind_gust_spd": 2.4,
#     "wind_spd": 1.54,
#     "place_name": "Hải Phòng"
#   },
#   {
#     "city_id": "1581298",
#     "city_name": "Haiphong",
#     "country_code": "VN",
#     "lat": 20.8623278,
#     "lon": 106.6799266,
#     "sources": [
#       "488251-99999",
#       "imerg",
#       "era5",
#       "sat",
#       "radar"
#     ],
#     "state_code": "13",
#     "station_id": "488251-99999",
#     "timezone": "Asia/Ho_Chi_Minh",
#     "app_temp": 23.8,
#     "azimuth": 105.3,
#     "clouds": 100,
#     "datetime": "2025-10-30:23",
#     "dewpt": 22,
#     "dhi": 7,
#     "dni": 18,
#     "elev_angle": 0.3,
#     "ghi": 2,
#     "h_angle": null,
#     "pod": "d",
#     "precip": 0,
#     "pres": 1014,
#     "revision_status": "final",
#     "revision_version": "2.1",
#     "rh": 94,
#     "slp": 1015,
#     "snow": 0,
#     "solar_rad": 7,
#     "temp": 23,
#     "timestamp_local": "2025-10-31T06:00:00",
#     "timestamp_utc": "2025-10-30T23:00:00",
#     "ts": 1761865200,
#     "uv": 0.6,
#     "vis": 8,
#     "weather": {
#       "icon": "c04n",
#       "code": 804,
#       "description": "Overcast clouds"
#     },
#     "wind_dir": 338,
#     "wind_gust_spd": 2.4,
#     "wind_spd": 1.03,
#     "place_name": "Hải Phòng"
#   }
# ]

# %%
def make_observation_id(source: str, lat: float, lon: float, ts: int) -> str:
    """
    This functions creates a unique observation ID.
    - source: the data source (e.g. weatherbit)
    - lat, lon: coordinates of the observation
    - ts: unix timestamp of the observation
    """
    if lat is None or lon is None or ts is None:
        return None
    
    key = f"{source}|{lat:.6}|{lon:.6}|{ts}"
    return hashlib.sha256(key.encode()).hexdigest()

# %%
def transform_to_bronze_df_historical(observations: list) -> pd.DataFrame:
    """
    Transform raw historical JSON data into a DataFrame matching the Bronze schema.
    This version also handles schema differences between the historical data and the current data.
    """
    if not observations:
        logging.info("No new observations to transform.")
        return pd.DataFrame()
    
    logging.info("Transforming raw data to Bronze schema...")
    transformed_records = []

    ingested_at = datetime.now(timezone.utc)
    ingest_date = ingested_at.strftime('%Y-%m-%d')

    for obs_data in observations:
        if 'wind_gust_spd' in obs_data:
            obs_data['gust'] = obs_data.pop('wind_gust_spd')

        if 'app_temp' not in obs_data:
            obs_data['app_temp'] = None
            
        if 'aqi' not in obs_data:
            obs_data['aqi'] = None

        lat = obs_data.get('lat')
        lon = obs_data.get('lon')
        ts = obs_data.get('ts')

        record = {
            "observation_id": make_observation_id("weatherbit_historical", lat, lon, ts),
            "source": "weatherbit_historical",
            "raw_payload": json.dumps(obs_data, ensure_ascii=False),
            "lat": lat,
            "lon": lon,
            "_ingested_at": ingested_at,
            "ingest_date": ingest_date,
        }

        transformed_records.append(record)

    df = pd.DataFrame(transformed_records)

    df['_ingested_at'] = pd.to_datetime(df['_ingested_at'])
    df['ingest_date'] = pd.to_datetime(df['ingest_date']).dt.date
    
    return df

# %%
print("Tesing the transformation function...")
bronze_df_test = transform_to_bronze_df_historical(test_res)

print(f"Transformed into a DataFrame with {len(bronze_df_test)} rows.")
bronze_df_test.info()

print("Sample of the first transformed record's raw_payload:")
sample_payload = json.loads(bronze_df_test.iloc[0]['raw_payload'])
print(json.dumps(sample_payload, indent=2, ensure_ascii=False))
# Out:
# 2025-11-21 12:50:10,838 - root - INFO - Transforming raw data to Bronze schema...
# Tesing the transformation function...
# Transformed into a DataFrame with 24 rows.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   observation_id  24 non-null     object
#  1   source          24 non-null     object
#  2   raw_payload     24 non-null     object
#  3   lat             24 non-null     float64
#  4   lon             24 non-null     float64
#  5   _ingested_at    24 non-null     datetime64[ns, UTC]
#  6   ingest_date     24 non-null     object
# dtypes: datetime64[ns, UTC](1), float64(2), object(4)
# memory usage: 1.4+ KB
# Sample of the first transformed record's raw_payload:
# {
#   "city_id": "1581298",
#   "city_name": "Haiphong",
#   "country_code": "VN",
#   "lat": 20.8623278,
#   "lon": 106.6799266,
#   "sources": [
#     "488251-99999",
#     "imerg",
#     "era5",
#     "sat",
#     "radar"
#   ],
#   "state_code": "13",
#   "station_id": "488251-99999",
#   "timezone": "Asia/Ho_Chi_Minh",
#   "app_temp": 23.8,
#   "azimuth": 110.9,
#   "clouds": 100,
#   "datetime": "2025-10-30:00",
#   "dewpt": 22,
#   "dhi": 64,
#   "dni": 574,
#   "elev_angle": 13.7,
#   "ghi": 193,
#   "h_angle": null,
#   "pod": "d",
#   "precip": 0,
#   "pres": 1015,
#   "revision_status": "final",
#   "revision_version": "2.1",
#   "rh": 94,
#   "slp": 1016,
#   "snow": 0,
#   "solar_rad": 70,
#   "temp": 23,
#   "timestamp_local": "2025-10-30T07:00:00",
#   "timestamp_utc": "2025-10-30T00:00:00",
#   "ts": 1761782400,
#   "uv": 0.7,
#   "vis": 16,
#   "weather": {
#     "icon": "c04d",
#     "code": 804,
#     "description": "Overcast clouds"
#   },
#   "wind_dir": 10,
#   "wind_spd": 2.06,
#   "place_name": "Hải Phòng",
#   "gust": 2.3,
#   "aqi": null
# }

# %%
def write_to_bronze(df: pd.DataFrame):
    """
    This function writes a DatFrame to a Delta table on MinIO, partitioned by ingest_date.
    """
    if df.empty:
        logging.info("DataFrame is empty. Skipping write to MinIO.")
        return

    logging.info(f"Writing {len(df)} records to Delta table: {BRONZE_TABLE_PATH}")

    arrow_table = pa.Table.from_pandas(df)

    write_deltalake(
        table_or_uri=BRONZE_TABLE_PATH,
        data=arrow_table,
        mode="append",
        partition_by=['ingest_date'],
        schema_mode="merge",
        storage_options=storage_options,
    )

    logging.info("Write operation completed successfully.")

# %%
run_full_pipeline = True
start_date_str = "2025-09-01"
end_date_str   = "2025-09-30"

if run_full_pipeline and locations_to_fetch:
    logging.info("Stating full pipeline...")

    raw_observations = fetch_historical_data(WEATHERBIT_API_KEY, locations_to_fetch, start_date_str, end_date_str)

    if raw_observations:
        bronze_df = transform_to_bronze_df_historical(raw_observations)
        write_to_bronze(bronze_df)
    
        logging.info("The historical ingestion pipeline completed successfully!")
else:
    print("The pipeline run was skipped. Set 'run_full_pipeline = True' to execute.")
# Out:
# 2025-11-21 12:50:10,862 - root - INFO - Stating full pipeline...
# 2025-11-21 12:50:10,863 - root - INFO - Fetching historical data from 2025-09-01 to 2025-09-30 for 34 locations.
# Fetching data for locations: 100%|██████████| 34/34 [01:19<00:00,  2.35s/it]
# 2025-11-21 12:51:30,765 - root - INFO - Total historical records fetched: 23664
# 2025-11-21 12:51:30,767 - root - INFO - Transforming raw data to Bronze schema...
# 2025-11-21 12:51:31,056 - root - INFO - Writing 23664 records to Delta table: s3://weather-bronze/weather_events
# 2025-11-21 12:51:31,283 - root - INFO - Write operation completed successfully.
# 2025-11-21 12:51:31,283 - root - INFO - The historical ingestion pipeline completed successfully!
