# %% [markdown]
# ## Geocode Wards of Quảng Ngãi (deprecated)
#
# ## This process is no longer part of the active pipeline and is retained only for traceability.
#
# Purpose: Assign geographic coordinates (latitude, longitude) to each ward/commune in Quảng Ngãi using the Nominatim (OpenStreetMap) API:
#
# - Read the ward list from quang_ngai_wards.csv.
# - Use the geocode_location function to query Nominatim API and retrieve coordinates for each ward.
# - Handle network errors and cases where no results are returned.
# - Save the results, including ward names and coordinates, to quang_ngai_wards_geocoded.csv.
#
# ### 1. Setup

# %%
import pandas as pd
import requests
import time
from pathlib import Path
from tqdm import tqdm

# %% [markdown]
# ### 2. Paths

# %%
project_root = Path.cwd()
input_csv_path = project_root / Path("..") / "resources" / "quang_ngai_wards.csv"
output_csv_path = project_root / Path("..") / "resources" / "quang_ngai_wards_geocoded.csv"

print(f"Input file path: {input_csv_path.resolve()}")
print(f"Output file path: {output_csv_path.resolve()}")
# Out:
# Input file path: /home/tan/geo-weather-lake/resources/quang_ngai_wards.csv
# Output file path: /home/tan/geo-weather-lake/resources/quang_ngai_wards_geocoded.csv

# %% [markdown]
# ### 3. Nominatim API URL

# %%
NOMINATIM_API_URL = "https://nominatim.openstreetmap.org/search"

# %% [markdown]
# ### 4. Load wards CSV

# %%
df_wards = pd.read_csv(input_csv_path)
df_wards
# Out:
#                  tenhc
# 0             Đăk Long
# 1              Đăk Môn
# 2             Dục Nông
# 3              Đăk Sao
# 4           Đăk Tờ Kan
# ..                 ...
# 91  Trương Quang Trọng
# 92             Đức Phổ
# 93             Măng Ri
# 94          Tu Mơ Rông
# 95              Lý Sơn
#
# [96 rows x 1 columns]

# %% [markdown]
# ### 5. Geocoding function

# %%
def geocode_location(query_string: str) -> tuple:
    params = {
        'q': query_string,
        'format': 'json',
        'addressdetails': 1,
        'limit': 1
    }

    headers = {
        'User-Agent': 'weather-de'
    }

    try:
        response = requests.get(NOMINATIM_API_URL, params=params, headers=headers)

        if response.status_code == 200:
            results = response.json()
            if results:
                top_result = results[0]
                lat = float(top_result.get('lat'))
                lon = float(top_result.get('lon'))
                return lat, lon
            else:
                print(f"No results found for query: {query_string}")
                return None, None
        else:
            print(f"API request failed for '{query_string}' with status code {response.status_code}")
            return None, None
    except requests.exceptions.RequestException as e:
        print(f"A network error occurred: {e}")
        return None, None

# %%
test_lat, test_lon = geocode_location("Lý Sơn, Quảng Ngãi, Việt Nam")
print(f"Test geocoding for 'Lý Sơn': Latitude={test_lat}, Longitude={test_lon}")
# Out:
# Test geocoding for 'Lý Sơn': Latitude=15.3809098, Longitude=109.1174595

# %% [markdown]
# ### 6. Batch Geocoding

# %%
geocoded_res = []
for i, row in tqdm(df_wards.iterrows(), total=len(df_wards)):
    ward_name = row['tenhc']
    query = f"{ward_name}, Quảng Ngãi, Việt Nam"
    lat, lon = geocode_location(query)
    geocoded_res.append({'latitude': lat, 'longitude': lon})
    time.sleep(1.1)
# Out:
# 100%|██████████| 96/96 [03:52<00:00,  2.43s/it]

# %%
df_coords = pd.DataFrame(geocoded_res)
geocoded_res
# Out:
# [{'latitude': 14.6300997, 'longitude': 107.9257688},
#  {'latitude': 14.8891081, 'longitude': 107.7088038},
#  {'latitude': 14.852787, 'longitude': 107.6759855},
#  {'latitude': 14.9271916, 'longitude': 107.8230721},
#  {'latitude': 14.7951793, 'longitude': 107.8659328},
#  {'latitude': 14.763761, 'longitude': 107.7626116},
#  {'latitude': 14.6995493, 'longitude': 107.8368625},
#  {'latitude': 14.6703991, 'longitude': 107.9523156},
#  {'latitude': 14.5635754, 'longitude': 108.0019313},
#  {'latitude': 14.7050728, 'longitude': 107.5629434},
#  {'latitude': 14.6177311, 'longitude': 107.6375198},
#  {'latitude': 14.6612477, 'longitude': 107.840036},
#  {'latitude': 14.4095371, 'longitude': 107.7951502},
#  {'latitude': 14.5200244, 'longitude': 107.7392226},
#  {'latitude': 14.1443394, 'longitude': 107.424164},
#  {'latitude': 14.3775557, 'longitude': 107.5458843},
#  {'latitude': 14.0933495, 'longitude': 107.5451485},
#  {'latitude': 14.3799656, 'longitude': 107.8565103},
#  {'latitude': 14.3159359, 'longitude': 107.8340144},
#  {'latitude': 15.1777301, 'longitude': 107.8028252},
#  {'latitude': 14.3952128, 'longitude': 107.9159617},
#  {'latitude': 14.3079882, 'longitude': 107.9036172},
#  {'latitude': 14.3184038, 'longitude': 108.0421757},
#  {'latitude': 14.5377396, 'longitude': 107.9208836},
#  {'latitude': 14.5133455, 'longitude': 107.9215147},
#  {'latitude': 15.0883944, 'longitude': 107.9291533},
#  {'latitude': 15.2486812, 'longitude': 107.6717448},
#  {'latitude': 15.0807103, 'longitude': 107.7291369},
#  {'latitude': 15.1140506, 'longitude': 107.8067918},
#  {'latitude': 14.8338408, 'longitude': 108.1976402},
#  {'latitude': 14.6014606, 'longitude': 108.2916225},
#  {'latitude': 14.6014606, 'longitude': 108.2916225},
#  {'latitude': 14.6540635, 'longitude': 108.126111},
#  {'latitude': 14.3406675, 'longitude': 107.9807771},
#  {'latitude': 14.4080877, 'longitude': 108.024159},
#  {'latitude': 14.5074001, 'longitude': 108.2475497},
#  {'latitude': 14.4298976, 'longitude': 108.1673924},
#  {'latitude': 14.4862722, 'longitude': 108.0394539},
#  {'latitude': 15.1205915, 'longitude': 108.8107389},
#  {'latitude': 15.2872189, 'longitude': 108.7586373},
#  {'latitude': 14.9683101, 'longitude': 108.4989357},
#  {'latitude': 14.9747991, 'longitude': 108.5244112},
#  {'latitude': 15.0031399, 'longitude': 108.5897345},
#  {'latitude': 15.0923145, 'longitude': 108.6758977},
#  {'latitude': 14.9694316, 'longitude': 108.3556047},
#  {'latitude': 15.1136144, 'longitude': 108.7343083},
#  {'latitude': 14.98766, 'longitude': 108.7005924},
#  {'latitude': 15.0404297, 'longitude': 108.7346364},
#  {'latitude': 15.1700691, 'longitude': 108.631627},
#  {'latitude': 15.2116389, 'longitude': 108.6549463},
#  {'latitude': 15.1970167, 'longitude': 108.7091094},
#  {'latitude': 15.2199489, 'longitude': 108.8036962},
#  {'latitude': 15.2087717, 'longitude': 108.4531172},
#  {'latitude': 15.2772086, 'longitude': 108.5874819},
#  {'latitude': 15.2767088, 'longitude': 108.6643623},
#  {'latitude': 15.2702781, 'longitude': 108.718608},
#  {'latitude': 14.9694316, 'longitude': 108.3556047},
#  {'latitude': 15.2560695, 'longitude': 108.3788464},
#  {'latitude': 15.1605532, 'longitude': 108.3386804},
#  {'latitude': 14.9747991, 'longitude': 108.5244112},
#  {'latitude': 15.1651942, 'longitude': 108.5343407},
#  {'latitude': 15.1480892, 'longitude': 108.4254793},
#  {'latitude': 14.9230053, 'longitude': 108.760607},
#  {'latitude': 15.0398992, 'longitude': 108.8820315},
#  {'latitude': 14.99107, 'longitude': 108.8971993},
#  {'latitude': 15.0044249, 'longitude': 108.8054064},
#  {'latitude': 15.0523547, 'longitude': 108.8489997},
#  {'latitude': 14.9669204, 'longitude': 108.7979366},
#  {'latitude': 15.0833796, 'longitude': 108.8390246},
#  {'latitude': 14.8625306, 'longitude': 108.5199118},
#  {'latitude': 14.9694316, 'longitude': 108.3556047},
#  {'latitude': 14.9464855, 'longitude': 108.6760404},
#  {'latitude': 14.9862642, 'longitude': 108.888603},
#  {'latitude': 14.888533, 'longitude': 108.9212313},
#  {'latitude': 14.8518176, 'longitude': 108.9373221},
#  {'latitude': 15.1212755, 'longitude': 108.8063933},
#  {'latitude': 14.7267738, 'longitude': 109.015994},
#  {'latitude': 14.7153239, 'longitude': 108.7406987},
#  {'latitude': 14.8435957, 'longitude': 108.6643979},
#  {'latitude': 14.8226908, 'longitude': 108.7783634},
#  {'latitude': 15.3018841, 'longitude': 108.7592861},
#  {'latitude': 15.1128694, 'longitude': 108.8112246},
#  {'latitude': 14.7419262, 'longitude': 108.5599152},
#  {'latitude': 14.7390812, 'longitude': 108.8696246},
#  {'latitude': 14.7153239, 'longitude': 108.7406987},
#  {'latitude': 14.7540644, 'longitude': 108.9761109},
#  {'latitude': 14.7419962, 'longitude': 108.7415155},
#  {'latitude': 15.1055107, 'longitude': 108.7939715},
#  {'latitude': 15.1205491, 'longitude': 108.859935},
#  {'latitude': 15.2410488, 'longitude': 108.8872811},
#  {'latitude': 15.1801741, 'longitude': 108.8605984},
#  {'latitude': 15.1587157, 'longitude': 108.7932872},
#  {'latitude': 14.8087189, 'longitude': 108.9571626},
#  {'latitude': 14.9565872, 'longitude': 107.927374},
#  {'latitude': 14.888138, 'longitude': 107.9553006},
#  {'latitude': 15.3809098, 'longitude': 109.1174595}]

# %% [markdown]
# ### 7. Combine results and check failed Geocodes

# %%
df_geocoded = pd.concat([df_wards.reset_index(drop=True), df_coords], axis=1)
df_geocoded
# Out:
#                  tenhc   latitude   longitude
# 0             Đăk Long  14.630100  107.925769
# 1              Đăk Môn  14.889108  107.708804
# 2             Dục Nông  14.852787  107.675985
# 3              Đăk Sao  14.927192  107.823072
# 4           Đăk Tờ Kan  14.795179  107.865933
# ..                 ...        ...         ...
# 91  Trương Quang Trọng  15.158716  108.793287
# 92             Đức Phổ  14.808719  108.957163
# 93             Măng Ri  14.956587  107.927374
# 94          Tu Mơ Rông  14.888138  107.955301
# 95              Lý Sơn  15.380910  109.117459
#
# [96 rows x 3 columns]

# %%
failed_count = df_geocoded['latitude'].isnull().sum()
failed_count
# Out:
# 0

# %% [markdown]
# ### 8. Save Geocoded CSV

# %%
df_geocoded.to_csv(output_csv_path, index=False)
